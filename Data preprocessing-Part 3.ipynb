# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 265  DECEMBER         25             Holmes & Watson
# 266  DECEMBER         25                        Vice
# 267  DECEMBER         25         On the Basis of Sex
# 268  DECEMBER         25                   Destroyer
# 269  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 265       Columbia Pictures / Gary Sanchez Productions
# 266          Annapurna Pictures / Plan B Entertainment
# 267                                     Focus Features
# 268                                 Annapurna Pictures
# 269                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 265  Etan Cohen (director/screenplay); Will Ferrell...
# 266  Adam McKay (director/screenplay); Christian Ba...
# 267  Mimi Leder (director); Daniel Stiepleman (scre...
# 268  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 269  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 265  [163]
# 266  [137]
# 267  [226]
# 268  [258]
# 269  [259]
#
# [270 rows x 7 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339' # Generate your API Key from: https://www.themoviedb.org/

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 265  DECEMBER         25             Holmes & Watson
# 266  DECEMBER         25                        Vice
# 267  DECEMBER         25         On the Basis of Sex
# 268  DECEMBER         25                   Destroyer
# 269  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 265       Columbia Pictures / Gary Sanchez Productions
# 266          Annapurna Pictures / Plan B Entertainment
# 267                                     Focus Features
# 268                                 Annapurna Pictures
# 269                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 265  Etan Cohen (director/screenplay); Will Ferrell...
# 266  Adam McKay (director/screenplay); Christian Ba...
# 267  Mimi Leder (director); Daniel Stiepleman (scre...
# 268  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 269  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
#
#       Ref.                                           genres
# 0      NaN                          Horror Mystery Thriller
# 1      NaN                                   Thriller Drama
# 2      NaN                                  Action Thriller
# 3      NaN                            Drama History Western
# 4      NaN                                  Action Thriller
# ..     ...                                              ...
# 265  [163]                   Mystery Adventure Comedy Crime
# 266  [137]        Thriller Science Fiction Action Adventure
# 267  [226]                                    Drama History
# 268  [258]                      Thriller Crime Drama Action
# 269  [259]  Science Fiction Mystery Drama Thriller TV Movie
#
# [270 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 265             Holmes & Watson
# 266                        Vice
# 267         On the Basis of Sex
# 268                   Destroyer
# 269  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 265  Etan Cohen (director/screenplay); Will Ferrell...
# 266  Adam McKay (director/screenplay); Christian Ba...
# 267  Mimi Leder (director); Daniel Stiepleman (scre...
# 268  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 269  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 265                   Mystery Adventure Comedy Crime
# 266        Thriller Science Fiction Action Adventure
# 267                                    Drama History
# 268                      Thriller Crime Drama Action
# 269  Science Fiction Mystery Drama Thriller TV Movie
#
# [270 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-12-4838efec492a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-14-94b1a1569c5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-16-75f2be6b779a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-18-c6969dc4d5e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 265             Holmes & Watson
# 266                        Vice
# 267         On the Basis of Sex
# 268                   Destroyer
# 269  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 265  Etan Cohen (director/screenplay); Will Ferrell...
# 266  Adam McKay (director/screenplay); Christian Ba...
# 267  Mimi Leder (director); Daniel Stiepleman (scre...
# 268  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 269  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                                    Action Thriller  Jaume Collet-Serra
# ..                                               ...                 ...
# 265                   Mystery Adventure Comedy Crime          Etan Cohen
# 266        Thriller Science Fiction Action Adventure          Adam McKay
# 267                                    Drama History          Mimi Leder
# 268                      Thriller Crime Drama Action        Karyn Kusama
# 269  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 265     Will Ferrell          John C. Reilly    Rebecca Hall
# 266   Christian Bale               Amy Adams    Steve Carell
# 267   Felicity Jones            Armie Hammer  Justin Theroux
# 268    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 269  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [270 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 265          Etan Cohen     Will Ferrell          John C. Reilly
# 266          Adam McKay   Christian Bale               Amy Adams
# 267          Mimi Leder   Felicity Jones            Armie Hammer
# 268        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 269         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                            Drama History Western
# 4    Patrick Wilson                                  Action Thriller
# ..              ...                                              ...
# 265    Rebecca Hall                   Mystery Adventure Comedy Crime
# 266    Steve Carell        Thriller Science Fiction Action Adventure
# 267  Justin Theroux                                    Drama History
# 268    Toby Kebbell                      Thriller Crime Drama Action
# 269   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 265             Holmes & Watson
# 266                        Vice
# 267         On the Basis of Sex
# 268                   Destroyer
# 269  Black Mirror: Bandersnatch
#
# [270 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 265          Etan Cohen     Will Ferrell          John C. Reilly
# 266          Adam McKay   Christian Bale               Amy Adams
# 267          Mimi Leder   Felicity Jones            Armie Hammer
# 268        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 269         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                                  Action Thriller
# ..              ...                                              ...
# 265    Rebecca Hall                   Mystery Adventure Comedy Crime
# 266    Steve Carell        Thriller Science Fiction Action Adventure
# 267  Justin Theroux                                    Drama History
# 268    Toby Kebbell                      Thriller Crime Drama Action
# 269   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 265             holmes & watson
# 266                        vice
# 267         on the basis of sex
# 268                   destroyer
# 269  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 265  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 266  Christian Bale Amy Adams Steve Carell Adam McK...
# 267  Felicity Jones Armie Hammer Justin Theroux Mim...
# 268  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 269  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [270 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239           Universal Pictures / DreamWorks Pictures
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
# [242 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-060ce728dee3> in <module>
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# D:\Software_Location\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# D:\Software_Location\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-060ce728dee3> in <lambda>(x)
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# <ipython-input-6-3c8c2f8da7a2> in get_genre(x)
#       3 def get_genre(x):
#       4     genres = []
# ----> 5     result = tmdb_movie.search(x)
#       6     movie_id = result[0].id
#       7     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
#
# D:\Software_Location\lib\site-packages\tmdbv3api\objs\movie.py in search(self, term, page)
#     220         """
#     221         return self._get_obj(
# --> 222             self._call(
#     223                 self._urls["search_movie"],
#     224                 "query=" + quote(term) + "&page=" + str(page),
#
# D:\Software_Location\lib\site-packages\tmdbv3api\tmdb.py in _call(self, action, append_to_response, call_cached, method, data)
#     129
#     130         if self.cache and self.obj_cached and call_cached and method != "POST":
# --> 131             req = self.cached_request(method, url, data)
#     132         else:
#     133             req = self._session.request(method, url, data=data)
#
# D:\Software_Location\lib\site-packages\tmdbv3api\tmdb.py in cached_request(method, url, data)
#     109     @lru_cache(maxsize=REQUEST_CACHE_MAXSIZE)
#     110     def cached_request(method, url, data):
# --> 111         return requests.request(method, url, data=data)
#     112
#     113     def cache_clear(self):
#
# D:\Software_Location\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\Software_Location\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\Software_Location\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# D:\Software_Location\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# D:\Software_Location\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# D:\Software_Location\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# D:\Software_Location\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\Software_Location\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# D:\Software_Location\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# D:\Software_Location\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# D:\Software_Location\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# D:\Software_Location\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# D:\Software_Location\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# D:\Software_Location\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df

# %%
final_df.isna().sum()

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()

# %%
final_df.to_csv('final_data.csv',index=False)
